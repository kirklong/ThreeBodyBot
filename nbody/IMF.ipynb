# %%
include("IMF.jl")
# Out:
# getMass (generic function with 2 methods)

# %%
using Plots
masses=getMass(100000)
# Out:
# 100000-element Array{Float64,1}:
#  1.3714019989069384
#  2.9727680634474485
#  2.289772147460159
#  0.5345452121554971
#  1.6007672702994278
#  2.9906093705932055
#  1.270311049951389
#  2.0364801277002402
#  0.5202472431903404
#  0.5417773217076616
#  0.5063308423027056
#  0.7868103782232059
#  0.5071643384423234
#  ⋮
#  0.5478303030098368
#  1.172927943692016
#  0.5904414735231441
#  0.779639479996691
#  1.0077071773058008
#  3.4737402948517797
#  0.9645474564147772
#  0.5387926383303703
#  1.0928428166286304
#  0.5577745133006656
#  3.2011561409461393
#  0.6644466899093331

# %%
histogram(masses,bins=150,yaxis=:log)

# %%
maximum(masses)
# Out:
# 149.48039092618637

# %%
intTen=(0.5^(-1.3)-10^(-1.3))/1.3
diff=N-intTen
# Out:
# 0.03741225192930231

# %%
sumTarget=rand(1:max1000,1)[1]/1000
# Out:
# 0.463

# %%
m=(0.5^(-1.3)-sumTarget)^(1.3)
# Out:
# 2.4611506632434166

# %%
sum(masses)/length(masses)
# Out:
# 3.3765036570614586

# %%
round(1.33,digits=1)
# Out:
# 1.3

# %%
round(masses[1],digits=1)
# Out:
# 1.4
