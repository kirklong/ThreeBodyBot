# %%
include("IMF.jl")
# Out:
# getMass (generic function with 2 methods)

# %%
using Plots
acceptedAlphaM1=1.3 
masses=getMass(100000,alphaM1=acceptedAlphaM1/10)
for i=1:3
    println("m$i = $(masses[i])")
end
histogram(masses,bins=150,yaxis=:log,xaxis=:log,xlims=[1,150])
# Out:
# m1 = 10.66
# m2 = 4.88
# m3 = 5.63

# %%
# Out:
# m1 = 29.6
# m2 = 131.94
# m3 = 60.19

# %%
maximum(masses)
# Out:
# 150.0

# %%
intTen=(0.5^(-1.3)-10^(-1.3))/1.3
diff=N-intTen
# Out:
# 0.03741225192930231

# %%
sumTarget=rand(1:max1000,1)[1]/1000
# Out:
# 0.463

# %%
m=(0.5^(-1.3)-sumTarget)^(1.3)
# Out:
# 2.4611506632434166

# %%
sum(masses)/length(masses)
# Out:
# 31.6713622

# %%
round(1.33,digits=1)
# Out:
# 1.3

# %%
round(masses[1],digits=1)
# Out:
# 1.4
